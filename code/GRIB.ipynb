# %%
import os

import pandas as pd
import numpy as np

import xarray as xr

# %%
path_d = "../data/ERA5/"

vars = [ 
    "u"
    ]

levels = [
    500
    ]

years = [
    1979
    ]

region = [
    "mexico"
    ]

i = 0

fname = ( vars[0] + "_" + str( levels[0] ) + "_"
    + str( years[0] ) + "_" + region[0] + ".grib" )

ds = xr.open_dataset( path_d + fname, engine = "cfgrib" )

ds = ds.resample(time = "1D").mean()

ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 365, latitude: 221, longitude: 281)
# Coordinates:
#   * time           (time) datetime64[ns] 1979-01-01 1979-01-02 ... 1979-12-31
#     number         int64 0
#     step           timedelta64[ns] 00:00:00
#     isobaricInhPa  int64 500
#   * latitude       (latitude) float64 50.0 49.75 49.5 49.25 ... -4.5 -4.75 -5.0
#   * longitude      (longitude) float64 -135.0 -134.8 -134.5 ... -65.25 -65.0
# Data variables:
#     u              (time, latitude, longitude) float32 15.44 15.54 ... -2.494
